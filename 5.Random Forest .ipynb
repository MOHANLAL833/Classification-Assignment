# %%
import pandas as pd

# %%
data=pd.read_csv("CKD.csv")
data
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
data=pd.get_dummies(data,drop_first=True)
data
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
data.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
data["classification_yes"].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
independent=data[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent=data[["classification_yes"]]

# %%
independent.shape
# Out:
# (399, 27)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[1,10,100,100],'criterion':['gini', 'entropy', 'log_loss']}
grid=GridSearchCV(RandomForestClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(xtrain,ytrain)
re=grid.cv_results_
grid_predicition=grid.predict(xtest)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,grid_predicition)
from sklearn.metrics import classification_report
clf_report=classification_report(ytest,grid_predicition)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\MOHANLAL\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(ytest,grid_predicition,average='weighted')
print("The best F1_score is {}:".format(grid.best_params_),f1_macro)
# Out:
# The best F1_score is {'criterion': 'gini', 'n_estimators': 100}: 0.9916844900066377

# %%
print("The confusion matrix is \n",cm)
# Out:
# The confusion matrix is
#  [[45  0]
#  [ 1 74]]

# %%
print("The classification report is \n",clf_report)
# Out:
# The classification report is
#                precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99        45
#         True       1.00      0.99      0.99        75
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(ytest,grid.predict_proba(xtest)[:,1])
# Out:
# 0.9997037037037038

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018384      0.002743         0.013791        0.000890
# 1        0.039740      0.004643         0.011367        0.003051
# 2        0.269418      0.009567         0.024683        0.003518
# 3        0.280123      0.016711         0.023000        0.001260
# 4        0.013581      0.002164         0.015721        0.001783
# 5        0.039699      0.004340         0.014761        0.001027
# 6        0.278587      0.006990         0.022570        0.001803
# 7        0.281777      0.007769         0.023690        0.001051
# 8        0.012681      0.002016         0.012877        0.001016
# 9        0.037191      0.002963         0.016229        0.002333
# 10       0.273515      0.007003         0.021374        0.002736
# 11       0.242401      0.009623         0.012121        0.006522
#
#    param_criterion param_n_estimators  \
# 0             gini                  1
# 1             gini                 10
# ...
